# %%
import pandas as pd
import seaborn as sns
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_excel('/Users/apple/Documents/ML_Project/ML - 2.1/result/result.xlsx',
                   index_col='model')
df
# Out:
#                              1. ws+wd  2. ws+wd-3  3. ws+wd-6  4. ws+sin(wd)  \
# model
# 1. default_linear_learner      0.0312      0.0370      0.0367         0.0249
# 2. default_tree_learner        0.0403      0.0433      0.0443         0.0421
# 3. lasso learner               0.0228      0.0313      0.0313         0.0217
# 4. linear_svr_learner          0.0245      0.0222      0.0205         0.0198
# 5. kernel_ridge_learner        0.0478      0.0380      0.3780         0.0341
# 6. esn_ridge_learner           0.0482      0.0379      0.0397         0.0521
# 7. esn_kernel_ridge_learner    0.0442      0.0382      0.0371         0.0257
# 8. esn_linear_svr_learner      0.0275      0.0352      0.0369         0.0171
#
#                              5. ws+cos(wd)  6. ws+cos(wd)-3  7. ws+cos(wd)-6  \
# model
# 1. default_linear_learner           0.0249           0.0371           0.0368
# 2. default_tree_learner             0.0408           0.4089           0.0423
# ...

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'
f, ax= plt.subplots(figsize=(15,6),nrows=1)
sns.heatmap(df, ax=ax, vmin=0.01, vmax=0.04, annot=True, fmt='.3f')
plt.xticks(rotation=20)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5]), <a list of 14 Text xticklabel objects>)

# %% [markdown]
# | model \ MSE                | ws+wd         | cos(wd)       | sin(wd)       | cos(wd)-3 | cos(wd)-6 |
# | -------------------------- | ------------- | ------------- | ------------- | --------- | --------- |
# | default_linear_learner     | 3. 0.0312     | 4. 0.0249     | 3. 0.0249     | 2. 0.0371 | 1. 0.0368 |
# | default_tree_learner       | 4. 0.0403     | 6. 0.0408     | 6. 0.0421     | 6. 0.4089 | 4. 0.0423 |
# | **linear_svr_learner**     | **1. 0.0245** | **1. 0.0189** | **2. 0.0198** | 7. 0.0593 | 5. 0.0594 |
# | kernel_ridge_learner       | 6. 0.0478     | 5. 0.0340     | 5. 0.0341     | 4. 0.0386 | 3. 0.0383 |
# | esn_ridge_learner          | 7. 0.0482     | 7. 0.0417     | 7. 0.0521     | 3. 0.0379 | 6. 0.9389 |
# | esn_kernel_ridge_learner   | 5. 0.0442     | **3. 0.0248** | **4. 0.0257** | 5. 0.0387 | 2. 0.0367 |
# | **esn_linear_svr_learner** | **2. 0.0275** | **2. 0.0216** | **1. 0.0171** | 1. 0.0368 | 无法收敛  |

# %%
import pandas as pd
import seaborn as sns
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_excel('/Users/apple/Documents/ML_Project/ML - 2.1/result/result.xlsx',
                   index_col='model')
df
# Out:
#                            ws+wd  ws+cos(wd)  ws+sin(wd)  ws+cos(wd)-3  \
# model
# default_linear_learner    0.0312      0.0249      0.0249        0.0371
# default_tree_learner      0.0403      0.0408      0.0421        0.4089
# linear_svr_learner        0.0245      0.0189      0.0198        0.0593
# kernel_ridge_learner      0.0478      0.0340      0.0341        0.0386
# esn_ridge_learner         0.0482      0.0417      0.0521        0.0379
# esn_kernel_ridge_learner  0.0442      0.0248      0.0257        0.0387
# esn_linear_svr_learner    0.0275      0.0216      0.0171        0.0368
#
#                           ws+cos(wd)-6  ws*cos(wd)  ws*sin(wd)  ws*cos(wd)-3
# model
# default_linear_learner          0.0368      0.0633      0.0632        0.0593
# default_tree_learner            0.0423      0.0633      0.0593        0.0528
# linear_svr_learner              0.0594      0.0593      0.0592        0.0593
# kernel_ridge_learner            0.0383      0.0474      0.0456        0.0315
# esn_ridge_learner               0.9389      0.0263      0.0258        0.0276
# esn_kernel_ridge_learner        0.0367      0.0704      0.0520        0.0464
# esn_linear_svr_learner             NaN      0.0594      0.0593        0.0594

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'
sns.heatmap(df,vmin=0.01, vmax=0.04, annot=True, fmt='.3f')
plt.xticks(rotation=20)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  <a list of 8 Text xticklabel objects>)
